# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/vaidhin/Image-Processing/blob/master/Pixel_Manipulation.ipynb)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
# %matplotlib inline

# %%
#This cell should be used when you run this file in Colab and upload image from your drive. Otherwise skip it
from google.colab import files
image = files.upload()
# Out:
#      <input type="file" id="files-2849d6b4-4744-4540-886f-ba0c01a1defd" name="files[]" multiple disabled />
#      <output id="result-2849d6b4-4744-4540-886f-ba0c01a1defd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving lane.jpg to lane (1).jpg

# %%
image = mpimg.imread('lane.jpg')

# %%
print('This image is: ',type(image), 
         'with dimensions:', image.shape )
# Out:
# ('This image is: ', <type 'numpy.ndarray'>, 'with dimensions:', (540, 960, 3))

# %%
test_Image = np.copy(image)

# %%
# Define our color selection criteria
red_threshold = 100
green_threshold = 100
blue_threshold = 100
rgb_threshold = [red_threshold, green_threshold, blue_threshold]

# %%
thresholds = (image[:,:,0] < rgb_threshold[0]) \
           | (image[:,:,1] < rgb_threshold[1]) \
            | (image[:,:,2] < rgb_threshold[2])
test_Image[thresholds] = [0,0,0]
plt.imshow(test_Image)
plt.show()

# %%
type(thresholds)
# Out:
# numpy.ndarray
