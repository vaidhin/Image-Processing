# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
img=mpimg.imread('1.jpg')

# %%
print(img)
# Out:
# [[[  0 108 183]
#   [  0 108 183]
#   [  0 108 183]
#   ...,
#   [ 11  66 149]
#   [ 11  66 149]
#   [ 13  65 149]]
#
#  [[  0 108 183]
#   [  0 108 183]
#   [  0 108 183]
#   ...,
#   [ 11  66 149]
#   [ 11  66 149]
#   [ 13  65 149]]
#
#  [[  1 109 184]
#   [  0 108 183]
#   [  0 108 183]
#   ...,
#   [ 10  66 149]
#   [ 10  66 149]
#   [ 13  65 149]]
#
#  ...,
#  [[ 40  22   8]
#   [ 64  48  23]
#   [ 79  82  35]
#   ...,
#   [ 51  74  30]
#   [ 48  71  27]
#   [ 39  42  21]]
#
#  [[ 49  24   4]
#   [ 68  47  18]
#   [ 81  83  36]
#   ...,
#   [ 47  65  23]
#   [ 46  64  22]
#   [ 38  37  17]]
#
#  [[ 59  25  23]
#   [ 73  45  42]
#   [ 80  80  42]
#   ...,
#   [ 48  63  22]
#   [ 48  65  23]
#   [ 33  30  11]]]

# %%
plt.imshow(img)

# %%
img.shape # displays the dimension of the array
# Out:
# (500, 750, 3)

# %%
len(img) #display total number of elements in the array
# Out:
# 500

# %%
print (img[:,:,0]) #print the channel 1 values in RGB channels
# Out:
# [[ 0  0  0 ..., 11 11 13]
#  [ 0  0  0 ..., 11 11 13]
#  [ 1  0  0 ..., 10 10 13]
#  ...,
#  [40 64 79 ..., 51 48 39]
#  [49 68 81 ..., 47 46 38]
#  [59 73 80 ..., 48 48 33]]

# %%
print (img[:,:,1]) ##print the channel 2 values in RGB channels
# Out:
# [[108 108 108 ...,  66  66  65]
#  [108 108 108 ...,  66  66  65]
#  [109 108 108 ...,  66  66  65]
#  ...,
#  [ 22  48  82 ...,  74  71  42]
#  [ 24  47  83 ...,  65  64  37]
#  [ 25  45  80 ...,  63  65  30]]

# %%
print (img[:,:,2]) #print the channel 3 values in RGB channels
# Out:
# [[183 183 183 ..., 149 149 149]
#  [183 183 183 ..., 149 149 149]
#  [184 183 183 ..., 149 149 149]
#  ...,
#  [  8  23  35 ...,  30  27  21]
#  [  4  18  36 ...,  23  22  17]
#  [ 23  42  42 ...,  22  23  11]]

# %%
len(img[1])
# Out:
# 750
